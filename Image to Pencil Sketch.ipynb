# %% [markdown]
# # LetsGrowMore DATA SCIENCE INTERNSHIP

# %% [markdown]
# # Task 2: Image to Pencil Sketch with Python

# %% [markdown]
# Level: Beginner

# %% [markdown]
# # Author: Usamah Momin

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np
import imageio
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Take image input and assign variable input to it

# %%
img = cv2.imread("E:\\LGM\\Car.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize = (8,8))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# # Converting Image to GrayScale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (8,8))
plt.imshow(gray, cmap = "gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# # Inverting the Image

# %%
invert = cv2.bitwise_not(gray)
plt.figure(figsize = (8,8))
plt.imshow(invert, cmap = "gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# # Image Smoothing

# %%
img_smoothing = cv2.GaussianBlur(invert, (21, 21), sigmaX = 0, sigmaY = 0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing, cmap = "gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# # Converting Image to Pencil Sketches

# %%
pencil = cv2.divide(gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(pencil,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# # Comparison of Original Image VS Final Sketch

# %%
plt.figure(figsize = (15,15))
plt.subplot(1,2,1)
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,2,2)
plt.imshow(pencil, cmap = "gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()
